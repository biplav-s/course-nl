# %%
## Data in - common-data/Example-TDBank-PersonalAcctAgree.txt
# Data fragments in multiple languages are:
text1 = "This is an important document. It contains the contract governing \
your deposit relationship with the Bank and required legal \
disclosures. Please have it translated. "

text2 = "Este es un documento importante. Contiene el contrato que \
rige su relación de depósitos con el Banco y declaraciones \
de información exigidas por ley. Por favor, mande a hacer la \
traducción de este documento. "

text3 = "Ce document est important. Il contient le contrat régissant vos \
rapports avec la Banque en votre qualité de déposant ainsi que \
les informations exigées par la loi. Veuillez le faire traduire. "

text4 = "Este documento é importante. Contém o contrato que governa \
a sua relação para depósitos com o banco e as declarações \
requeridas por lei.  Por favor mande traduzir. "

# %%
# Do imports
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text1 + text2 + text3 + text4)

# %%
# Print tokens and lemmas
print ([(token.text, token.lemma_) for token in doc])
# Out:
# [('This', 'this'), ('is', 'be'), ('an', 'an'), ('important', 'important'), ('document', 'document'), ('.', '.'), ('It', '-PRON-'), ('contains', 'contain'), ('the', 'the'), ('contract', 'contract'), ('governing', 'govern'), ('your', '-PRON-'), ('deposit', 'deposit'), ('relationship', 'relationship'), ('with', 'with'), ('the', 'the'), ('Bank', 'Bank'), ('and', 'and'), ('required', 'require'), ('legal', 'legal'), ('disclosures', 'disclosure'), ('.', '.'), ('Please', 'please'), ('have', 'have'), ('it', '-PRON-'), ('translated', 'translate'), ('.', '.'), ('Este', 'Este'), ('es', 'es'), ('un', 'un'), ('documento', 'documento'), ('importante', 'importante'), ('.', '.'), ('Contiene', 'Contiene'), ('el', 'el'), ('contrato', 'contrato'), ('que', 'que'), ('rige', 'rige'), ('su', 'su'), ('relación', 'relación'), ('de', 'de'), ('depósitos', 'depósitos'), ('con', 'con'), ('el', 'el'), ('Banco', 'Banco'), ('y', 'y'), ('declaraciones', 'declaracione'), ('de', 'de'), ('información', 'información'), ('exigidas', 'exigidas'), ('por', 'por'), ('ley', 'ley'), ('.', '.'), ('Por', 'Por'), ('favor', 'favor'), (',', ','), ('mande', 'mande'), ('a', 'a'), ('hacer', 'hacer'), ('la', 'la'), ('traducción', 'traducción'), ('de', 'de'), ('este', 'este'), ('documento', 'documento'), ('.', '.'), ('Ce', 'Ce'), ('document', 'document'), ('est', 'est'), ('important', 'important'), ('.', '.'), ('Il', 'Il'), ('contient', 'contient'), ('le', 'le'), ('contrat', 'contrat'), ('régissant', 'régissant'), ('vos', 'vos'), ('rapports', 'rapport'), ('avec', 'avec'), ('la', 'la'), ('Banque', 'Banque'), ('en', 'en'), ('votre', 'votre'), ('qualité', 'qualité'), ('de', 'de'), ('déposant', 'déposant'), ('ainsi', 'ainsi'), ('que', 'que'), ('les', 'les'), ('informations', 'informations'), ('exigées', 'exigées'), ('par', 'par'), ('la', 'la'), ('loi', 'loi'), ('.', '.'), ('Veuillez', 'Veuillez'), ('le', 'le'), ('faire', 'faire'), ('traduire', 'traduire'), ('.', '.'), ('Este', 'este'), ('documento', 'documento'), ('é', 'é'), ('importante', 'importante'), ('.', '.'), ('Contém', 'Contém'), ('o', 'o'), ('contrato', 'contrato'), ('que', 'que'), ('governa', 'governa'), ('a', 'a'), ('sua', 'sua'), ('relação', 'relação'), ('para', 'para'), ('depósitos', 'depósitos'), ('com', 'com'), ('o', 'o'), ('banco', 'banco'), ('e', 'e'), ('as', 'as'), ('declarações', 'declarações'), ('requeridas', 'requeridas'), ('por', 'por'), ('lei', 'lei'), ('.', '.'), (' ', ' '), ('Por', 'Por'), ('favor', 'favor'), ('mande', 'mande'), ('traduzir', 'traduzir'), ('.', '.')]

# %%
# Parts of speech
for token in doc:
    print (token, token.tag_, token.pos_, spacy.explain(token.tag_))
# Out:
# This DT DET determiner
# is VBZ AUX verb, 3rd person singular present
# an DT DET determiner
# important JJ ADJ adjective
# document NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# It PRP PRON pronoun, personal
# contains VBZ VERB verb, 3rd person singular present
# the DT DET determiner
# contract NN NOUN noun, singular or mass
# governing VBG VERB verb, gerund or present participle
# your PRP$ DET pronoun, possessive
# deposit NN NOUN noun, singular or mass
# relationship NN NOUN noun, singular or mass
# with IN ADP conjunction, subordinating or preposition
# the DT DET determiner
# Bank NNP PROPN noun, proper singular
# and CC CCONJ conjunction, coordinating
# required VBD VERB verb, past tense
# legal JJ ADJ adjective
# disclosures NNS NOUN noun, plural
# . . PUNCT punctuation mark, sentence closer
# Please UH INTJ interjection
# have VB AUX verb, base form
# it PRP PRON pronoun, personal
# translated VBN VERB verb, past participle
# . . PUNCT punctuation mark, sentence closer
# Este NNP PROPN noun, proper singular
# es NNP PROPN noun, proper singular
# un NNP PROPN noun, proper singular
# documento NNP PROPN noun, proper singular
# importante NNP PROPN noun, proper singular
# . . PUNCT punctuation mark, sentence closer
# Contiene NNP PROPN noun, proper singular
# el NNP PROPN noun, proper singular
# contrato NNP PROPN noun, proper singular
# que NNP PROPN noun, proper singular
# rige NNP PROPN noun, proper singular
# su NNP PROPN noun, proper singular
# relación NNP PROPN noun, proper singular
# de NNP PROPN noun, proper singular
# depósitos NNP PROPN noun, proper singular
# con XX X unknown
# el NNP PROPN noun, proper singular
# Banco NNP PROPN noun, proper singular
# y NNP PROPN noun, proper singular
# declaraciones NNS NOUN noun, plural
# de IN ADP conjunction, subordinating or preposition
# información NNP PROPN noun, proper singular
# exigidas NNP PROPN noun, proper singular
# por VBP VERB verb, non-3rd person singular present
# ley NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# Por NNP PROPN noun, proper singular
# favor VBP VERB verb, non-3rd person singular present
# , , PUNCT punctuation mark, comma
# mande NNP PROPN noun, proper singular
# a DT DET determiner
# hacer FW X foreign word
# la FW X foreign word
# traducción NNP PROPN noun, proper singular
# de FW X foreign word
# este NNP PROPN noun, proper singular
# documento NNP PROPN noun, proper singular
# . . PUNCT punctuation mark, sentence closer
# Ce NNP PROPN noun, proper singular
# document NN NOUN noun, singular or mass
# est NNP PROPN noun, proper singular
# important JJ ADJ adjective
# . . PUNCT punctuation mark, sentence closer
# Il NNP PROPN noun, proper singular
# contient NNP PROPN noun, proper singular
# le NNP PROPN noun, proper singular
# contrat VBP VERB verb, non-3rd person singular present
# régissant JJ ADJ adjective
# vos NNP PROPN noun, proper singular
# rapports NNS NOUN noun, plural
# avec NN NOUN noun, singular or mass
# la FW X foreign word
# Banque NNP PROPN noun, proper singular
# en NNP PROPN noun, proper singular
# votre NNP PROPN noun, proper singular
# qualité NNP PROPN noun, proper singular
# de NNP PROPN noun, proper singular
# déposant NNP PROPN noun, proper singular
# ainsi NNP PROPN noun, proper singular
# que NNP PROPN noun, proper singular
# les NNP PROPN noun, proper singular
# informations NNPS PROPN noun, proper plural
# exigées VBP VERB verb, non-3rd person singular present
# par NN NOUN noun, singular or mass
# la NNP PROPN noun, proper singular
# loi NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# Veuillez NNP PROPN noun, proper singular
# le NNP PROPN noun, proper singular
# faire NN NOUN noun, singular or mass
# traduire NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# Este VB VERB verb, base form
# documento NNP PROPN noun, proper singular
# é NN NOUN noun, singular or mass
# importante NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer
# Contém NNP PROPN noun, proper singular
# o DT DET determiner
# contrato NNP PROPN noun, proper singular
# que NNP PROPN noun, proper singular
# governa NNP PROPN noun, proper singular
# a DT DET determiner
# sua NNP PROPN noun, proper singular
# relação NNP PROPN noun, proper singular
# para NNP PROPN noun, proper singular
# depósitos NNP PROPN noun, proper singular
# com NNP PROPN noun, proper singular
# o NNP PROPN noun, proper singular
# banco NNP PROPN noun, proper singular
# e NNP PROPN noun, proper singular
# as IN SCONJ conjunction, subordinating or preposition
# declarações NNP PROPN noun, proper singular
# requeridas NNP PROPN noun, proper singular
# por NNP PROPN noun, proper singular
# lei NNP PROPN noun, proper singular
# . . PUNCT punctuation mark, sentence closer
#   _SP SPACE None
# Por NNP PROPN noun, proper singular
# favor VBP VERB verb, non-3rd person singular present
# mande JJ ADJ adjective
# traduzir NN NOUN noun, singular or mass
# . . PUNCT punctuation mark, sentence closer

# %%
# Chunking to get nouns
for chunk in doc.noun_chunks:
    print (chunk)
# Out:
# an important document
# It
# the contract
# your deposit relationship
# the Bank
# legal disclosures
# it
# Este
# un documento importante
# el Banco
# y
# por ley
# Por
# mande
# la traducción de este documento
# Ce document
# est
# contient le contrat régissant vos rapports
# la Banque
# votre
# par
# la loi
# Veuillez le faire traduire
# Este documento é importante
# Contém o contrato que governa
# a sua relação
# para depósitos com
# o banco
# e
# declarações requeridas por lei
# Por
# mande traduzir

# %%
# Do import
import textacy

# %%
# Make internal obj
new_doc = textacy.make_spacy_doc(text1 + text2 + text3 + text4,  lang='en_core_web_sm')

# %%
# Parse for verb specification
pattern = r'(<VERB>?<ADV>*<VERB>+)'
verb_phrases = textacy.extract.pos_regex_matches(new_doc, pattern)

# %%
for chunk in verb_phrases:
    print(chunk.text)
# Out:
# contains
# governing
# required
# translated
# por
# favor
# contrat
# exigées
# Este
# favor
# /Users/biplavs/opt/anaconda3/lib/python3.7/site-packages/textacy/extract.py:338: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   action="once",

# %%
# Dependency graphs in different languages
# Show dependency graph
from spacy import displacy

# %%
doc = nlp(text1)
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dca65d3ef9364d949ef00d098bf67764-0" class="displacy" width="4250" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">important</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">document.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">contains</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">contract</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">governing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">deposit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">relationship</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Bank</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">required</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">legal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">disclosures.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Please</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">translated.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dca65d3ef9364d949ef00d098bf67764-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dca65d3ef9364d949ef00d098bf67764-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dca65d3ef9364d949ef00d098bf67764-0-1" stroke-width="2px" d="M420,439.5 C420,264.5 735.0,264.5 735.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dca65d3ef9364d949ef00d098bf67764-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dca65d3ef9364d949ef00d098bf67764-0-2" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dca65d3ef9364d949ef00d098bf67764-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587

# %%
doc = nlp(text2)
displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="37e405f7785f419fb0a5c1a318654880-0" class="displacy" width="6000" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Este</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">documento</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">importante.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Contiene</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">contrato</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">rige</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">relación</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">depósitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">con</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Banco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">declaraciones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">información</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">exigidas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">ley.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">favor,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">mande</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">hacer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">traducción</tspan>
#     <tspan class="displacy-tag"
